# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
#UCI Dataset student-mat
dataset_mat = pd.read_csv(
    "student-mat.csv",
  header=None,skiprows=1,
    names=["School", "Sex", "Age", "Address","FamilySize","ParentsStatus","MothersEducation","FathersEducation","MothersJob",
           "FathersJob", "Reason", "StudentsGuardian", "TravelTime", "StudyTime", "Failures"
          ,"ShcoolSupport", "FamilySupport", "ExtraClasses", "Activities", "NurserySchool", "HigherEducation"
          ,"InternetAccess", "Relationship", "FamilyRelationships", "FreeTime", "GoingOut"
          ,"DailyAlcohol", "WeeklyAlcohol", "Health", "Absences", "G1", "G2", "G3"])

dataset_mat.head()
# Out:
#   School Sex  Age Address FamilySize ParentsStatus  MothersEducation  \
# 0     GP   F   18       U        GT3             A                 4
# 1     GP   F   17       U        GT3             T                 1
# 2     GP   F   15       U        LE3             T                 1
# 3     GP   F   15       U        GT3             T                 4
# 4     GP   F   16       U        GT3             T                 3
#
#    FathersEducation MothersJob FathersJob  ... FamilyRelationships FreeTime  \
# 0                 4    at_home    teacher  ...                   4        3
# 1                 1    at_home      other  ...                   5        3
# 2                 1    at_home      other  ...                   4        3
# 3                 2     health   services  ...                   3        2
# 4                 3      other      other  ...                   4        3
#
#    GoingOut  DailyAlcohol  WeeklyAlcohol Health Absences  G1  G2  G3
# 0         4             1              1      3        6   5   6   6
# 1         3             1              1      3        4   5   5   6
# 2         2             2              3      3       10   7   8  10
# 3         2             1              1      5        2  15  14  15
# 4         2             1              2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#UCI Dataset student-por
dataset_por = pd.read_csv(
    "student-por.csv",
  header=None,skiprows=1,
    names=["School", "Sex", "Age", "Address","FamilySize","ParentsStatus","MothersEducation","FathersEducation","MothersJob",
           "FathersJob", "Reason", "StudentsGuardian", "TravelTime", "StudyTime", "Failures"
          ,"ShcoolSupport", "FamilySupport", "ExtraClasses", "Activities", "NurserySchool", "HigherEducation"
          ,"InternetAccess", "Relationship", "FamilyRelationships", "FreeTime", "GoingOut"
          ,"DailyAlcohol", "WeeklyAlcohol", "Health", "Absences", "G1", "G2", "G3"])

dataset_por.head()
# Out:
#   School Sex  Age Address FamilySize ParentsStatus  MothersEducation  \
# 0     GP   F   18       U        GT3             A                 4
# 1     GP   F   17       U        GT3             T                 1
# 2     GP   F   15       U        LE3             T                 1
# 3     GP   F   15       U        GT3             T                 4
# 4     GP   F   16       U        GT3             T                 3
#
#    FathersEducation MothersJob FathersJob  ... FamilyRelationships FreeTime  \
# 0                 4    at_home    teacher  ...                   4        3
# 1                 1    at_home      other  ...                   5        3
# 2                 1    at_home      other  ...                   4        3
# 3                 2     health   services  ...                   3        2
# 4                 3      other      other  ...                   4        3
#
#    GoingOut  DailyAlcohol  WeeklyAlcohol Health Absences  G1  G2  G3
# 0         4             1              1      3        4   0  11  11
# 1         3             1              1      3        2   9  11  11
# 2         2             2              3      3        6  12  13  12
# 3         2             1              1      5        0  14  14  14
# 4         2             1              2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
columns = ["School", "Sex", "Age", "Address","FamilySize","ParentsStatus","MothersEducation","FathersEducation","MothersJob",
           "FathersJob", "Reason", "StudentsGuardian", "TravelTime", "StudyTime", "Failures"
          ,"ShcoolSupport", "FamilySupport", "ExtraClasses", "Activities", "NurserySchool", "HigherEducation"
          ,"InternetAccess", "Relationship", "FamilyRelationships", "FreeTime", "GoingOut"
          ,"DailyAlcohol", "WeeklyAlcohol", "Health", "Absences", "G1", "G2", "G3"]

# %%
# Specify the column name or index containing the binary elements
column_name = 'School'

# Mapping dictionary
mapping = {"GP": 0, "MS": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'Sex'

# Mapping dictionary
mapping = {"F": 0, "M": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'Address'

# Mapping dictionary
mapping = {"U": 0, "R": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'FamilySize'

# Mapping dictionary
mapping = {"LE3": 0, "GT3": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'ParentsStatus'

# Mapping dictionary
mapping = {"A": 0, "T": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'MothersJob'

# Mapping dictionary
mapping = {"teacher": 0, "health": 1, "services": 2, "at_home": 3, "other": 4 }
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'FathersJob'

# Mapping dictionary
mapping = {"teacher": 0, "health": 1, "services": 2, "at_home": 3, "other": 4 }
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'Reason'

# Mapping dictionary
mapping = {"home": 0, "reputation": 1, "course": 2, "other": 3}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'StudentsGuardian'

# Mapping dictionary
mapping = {"mother": 0, "father": 1, "other": 2}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'ShcoolSupport'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'FamilySupport'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'ExtraClasses'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'Activities'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'NurserySchool'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'HigherEducation'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'InternetAccess'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Specify the column name or index containing the binary elements
column_name = 'Relationship'

# Mapping dictionary
mapping = {"no": 0, "yes": 1}
dataset_mat[column_name] = dataset_mat[column_name].map(mapping)
dataset_por[column_name] = dataset_por[column_name].map(mapping)

# %%
# Calculate the correlation matrix
correlation_matrix = dataset_mat.corr().round(3)

# Filter the correlation matrix based on the condition
high_correlation = correlation_matrix[(correlation_matrix > 0.5) | (correlation_matrix < -0.5)]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(20, 16))

# Create a correlation matrix table
table = ax.table(cellText=high_correlation.values,
                 rowLabels=high_correlation.index,
                 colLabels=high_correlation.columns,
                 loc='center')

# Modify the table appearance
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Remove axis labels
ax.axis('off')

# Display the table
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = dataset_por.corr().round(3)

# Filter the correlation matrix based on the condition
high_correlation = correlation_matrix[(correlation_matrix > 0.5) | (correlation_matrix < -0.5)]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(20, 16))

# Create a correlation matrix table
table = ax.table(cellText=high_correlation.values,
                 rowLabels=high_correlation.index,
                 colLabels=high_correlation.columns,
                 loc='center')

# Modify the table appearance
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Remove axis labels
ax.axis('off')

# Display the table
plt.show()

# %%
# Drop the columns with high correlation
dataset_mat_filtered = dataset_mat.drop(["FathersEducation","MothersJob","WeeklyAlcohol","G2", "G3" ], axis=1)
dataset_por_filtered = dataset_por.drop(["FathersEducation","MothersJob","WeeklyAlcohol","G2", "G3" ], axis=1)

# %%
import numpy as np

def map_values(value):
    if int(value) > 15:
        return 2
    elif int(value) > 10:
        return 1
    else:
        return 0

# Example dataset
#dataset = np.random.uniform(0, 20, size=100)  # Generate random dataset
column_name = 'G1'
# Apply mapping function to each value in the dataset
dataset_mat_filtered[column_name] = np.array([map_values(value) for value in dataset_mat_filtered[column_name]])

# %%
X = dataset_mat_filtered.drop(["G1"], axis=1)
y = dataset_mat_filtered["G1"]

#Get 80% of data for training and 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.2, stratify=y)
y_train.value_counts()
# Out:
# 0    154
# 1    129
# 2     33
# Name: G1, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report

models = [
    ['RandomForest',RandomForestClassifier(n_estimators=50, max_depth=20, criterion="gini", random_state=42)],
    ['LinearRegression',LinearRegression()],
    ['DecisionTree', DecisionTreeClassifier(criterion="entropy", max_depth=20)],
    ['SVM',SVC(degree=6,kernel = "poly")]
]

for m in models:
    print(m[0])
    m[1].fit(X_train, y_train)
    y_pred = [round(x) for x in m[1].predict(X_test)]
    print(classification_report(y_pred,y_test))
# Out:
# RandomForest
#               precision    recall  f1-score   support
#
#            0       0.72      0.57      0.64        49
#            1       0.50      0.53      0.52        30
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.56        79
#    macro avg       0.41      0.37      0.38        79
# weighted avg       0.64      0.56      0.59        79
#
# LinearRegression
#               precision    recall  f1-score   support
#
#            0       0.49      0.73      0.58        26
#            1       0.78      0.47      0.59        53
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.56        79
#    macro avg       0.42      0.40      0.39        79
# weighted avg       0.68      0.56      0.59        79
#
# DecisionTree
#               precision    recall  f1-score   support
#
#            0       0.59      0.49      0.53        47
#            1       0.41      0.54      0.46        24
#            2       0.00      0.00      0.00         8
#
#     accuracy                           0.46        79
#    macro avg       0.33      0.34      0.33        79
# weighted avg       0.47      0.46      0.46        79
#
# SVM
#               precision    recall  f1-score   support
#
#            0       0.62      0.53      0.57        45
#            1       0.44      0.44      0.44        32
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.48        79
#    macro avg       0.35      0.32      0.34        79
# weighted avg       0.53      0.48      0.50        79
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rf = models[0][1]
plt.title("Random Forest - Feature Importance")
sns.barplot(y=X_train.columns,x=rf.feature_importances_, orient='h')
# Out:
# <Axes: title={'center': 'Random Forest - Feature Importance'}>

# %%
lr = models[1][1]
plt.title("Linear Regression - Feature Importance")
sns.barplot(y=X_train.columns,x=lr.coef_, orient='h')
# Out:
# <Axes: title={'center': 'Linear Regression - Feature Importance'}>

# %%
# Calculate the confusion matrix
confusion = confusion_matrix(y_test, models[0][1].predict(X_test))

# Define class labels
class_labels = ['NotPass', 'Pass', 'HighPass']

# Create a DataFrame for the confusion matrix
confusion_df = pd.DataFrame(confusion, index=class_labels, columns=class_labels)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Calculate the confusion matrix
confusion = confusion_matrix(y_test, models[2][1].predict(X_test))

# Define class labels
class_labels = ['NotPass', 'Pass', 'HighPass']

# Create a DataFrame for the confusion matrix
confusion_df = pd.DataFrame(confusion, index=class_labels, columns=class_labels)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Calculate the confusion matrix
confusion = confusion_matrix(y_test, models[3][1].predict(X_test))

# Define class labels
class_labels = ['NotPass', 'Pass', 'HighPass']

# Create a DataFrame for the confusion matrix
confusion_df = pd.DataFrame(confusion, index=class_labels, columns=class_labels)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
